# %% [markdown]
# # Faithful explanations for estimation-based fault detection under modeling error
#
# Run the full experiment end-to-end in the browser. It clones the repository,
# installs dependencies, runs `reproduce.py`, then shows the summary table and the
# figure. Everything is seeded, so the output matches the repository.
#
# Run the cells in order (Runtime → Run all).

# %% [markdown]
# ## 1. Clone the repository

# %%
# !git clone https://github.com/NiliRahmani/estimation-fault-xai.git
# %cd estimation-fault-xai
# Out:
# Cloning into 'estimation-fault-xai'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 27 (delta 2), reused 27 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 43.70 KiB | 733.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/estimation-fault-xai

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 3. Run the experiment
#
# Writes `results/summary_table.csv`, `results/metrics_raw.csv`, and
# `results/figure1_faithfulness.png`.

# %%
# !python reproduce.py
# Out:
# === Summary (mean over 20 seeds per condition) ===
# estimator condition  detection_rate  false_alarm_rate  mean_latency_steps  rmse  faith_model_mean  faith_model_std  faith_random_mean
#    Kalman   nominal           1.000             0.008               0.000 0.118             0.790            0.120              0.331
#    Kalman  mismatch           1.000             0.677               0.000 0.158             0.602            0.090              0.331
# SIF-style   nominal           1.000             0.009               0.000 0.171             0.369            0.298              0.331
# SIF-style  mismatch           1.000             0.353               0.000 0.180             0.354            0.248              0.331
#
# Figure written to /content/estimation-fault-xai/results/figure1_faithfulness.png
# Tables written to results/metrics_raw.csv and results/summary_table.csv

# %% [markdown]
# ## 4. Summary table

# %%
import pandas as pd
pd.read_csv("results/summary_table.csv")
# Out:
#    estimator condition  detection_rate  false_alarm_rate  mean_latency_steps  \
# 0     Kalman   nominal             1.0          0.007778                 0.0
# 1     Kalman  mismatch             1.0          0.677500                 0.0
# 2  SIF-style   nominal             1.0          0.009444                 0.0
# 3  SIF-style  mismatch             1.0          0.353333                 0.0
#
#        rmse  faith_model_mean  faith_model_std  faith_random_mean
# 0  0.118253           0.79025         0.120235            0.33125
# 1  0.157572           0.60225         0.089743            0.33125
# 2  0.171470           0.36900         0.297961            0.33125
# 3  0.179989           0.35425         0.247882            0.33125

# %% [markdown]
# ## 5. Figure: faithfulness, Kalman vs SIF-style, nominal vs mismatch

# %%
from IPython.display import Image
Image("results/figure1_faithfulness.png")
